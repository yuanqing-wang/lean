# %%
# %load_ext autoreload
# %autoreload 2
import jax
from lean.schedules import SinRBFSchedule

# %%
schedule = SinRBFSchedule.init(jax.random.PRNGKey(5), 10)

# %%
linspace = jax.numpy.linspace(0, 1, 100)
import matplotlib.pyplot as plt
y = [schedule(x) for x in linspace]
plt.plot(linspace, y)
